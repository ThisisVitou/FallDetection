# %% [markdown]
# #### Importing library

# %%
import cv2
import mediapipe as mp
import numpy as np
import time

# %%
from tensorflow.keras.models import load_model

# %% [markdown]
# #### load model

# %%
model = load_model('new_model.keras')
actions = np.array(['falling0', 'lying', 'sitting', 'standing'])

# %%
def extract_keypoints(results):
    pose_tmp = []
    
    if results.pose_landmarks:
        mpDraw.draw_landmarks(img, results.pose_landmarks,mpPose.POSE_CONNECTIONS)
        for res in results.pose_landmarks.landmark:
            test = np.array([res.x, res.y, res.z, res.visibility])
            pose_tmp.append(test)
    else:
        pose_tmp = [np.zeros(4) for _ in range(33)]

    return pose_tmp

# %% [markdown]
# #### test with opencv

# %%
mpPose = mp.solutions.pose
mpDraw = mp.solutions.drawing_utils

sequence = []
sentence = []
predictions = []
threshold = 0.5

pose = mpPose.Pose()
cap = cv2.VideoCapture(0)
pTime = 0

while True:
    success, img = cap.read()
    if not success:
        # No more frames to read (video ended)
        break
    
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = pose.process(imgRGB)
    # print(results.pose_landmarks)
    
    if results.pose_landmarks:
        mpDraw.draw_landmarks(img, results.pose_landmarks,mpPose.POSE_CONNECTIONS)

        keypoints = extract_keypoints(results)
        keyflat = np.array(keypoints).flatten()
        sequence.insert(0,keyflat)
        sequence = sequence[:30]

        # last_action = None

        # if len(sequence) == 30:
        #     res = model.predict(np.expand_dims(sequence, axis=0))[0]
        #     print(actions[np.argmax(res)])

        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predicted_action = actions[np.argmax(res)]
            print(predicted_action)
            cv2.putText(img, predicted_action, (10, 150), 
                    cv2.FONT_HERSHEY_PLAIN, 3, (0, 0, 255), 3, cv2.LINE_AA)


    cTime = time.time()
    fps = 1/(cTime-pTime)
    pTime = cTime

    cv2.putText(img, str(int(fps)), (10,50), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0, 0), 3)
    cv2.imshow("Image", img)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# standing
# ...
